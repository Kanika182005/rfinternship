# %%
def prime(num):
    if num <=1:
        return "Not a prime number"
    
    count=0
    for i in range(1,num+1):
        if num%i==0 :
            count+=1
    if count==2:
        return  num," is prime number" 
    else:
        return "Number is not prime" 
    
num= int(input("enter number for checking:"))
prime(num)
# Out:
# (11, ' is prime number')

# %%
def large(*args):
    max= args[0]
    for num in args:
        if num > max: 
            max= num
    return max
result=large(10,20,30,4,8,2,55,67,91,99)
print("Largest number is", result)
# Out:
# Largest number is 99

# %%
def student(**kwargs):
    return(kwargs)
student(name="kanika", age=21, course="btech")
# Out:
# {'name': 'kanika', 'age': 21, 'course': 'btech'}

# %%
def calculate(*args):
    maximum=max(args)
    minimum=min(args)
    total= sum(args)
    average=total/len(args)

    return maximum, minimum, total, average
result =calculate(10,20,45,23,5,78,98)
print("Maximun is", result[0])
print("Minimun is",result[1])
print("Total is", result[2])
print("Average is", result[3])
# Out:
# Maximun is 98
# Minimun is 5
# Total is 279
# Average is 39.857142857142854
