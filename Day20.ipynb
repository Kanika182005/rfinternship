# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create Dataset

np.random.seed(42)

data = {
    "Product": np.random.choice(
        ["Laptop", "Mobile", "Tablet", "Headphone"],100 ),

    "Region": np.random.choice(
        ["North", "South", "East", "West"],100 ),

    "Sales": np.random.randint( 5000,50000,100),

    "Quantity": np.random.randint(1,20,100)
}

df = pd.DataFrame(data)

print("Dataset")
print(df.head())

# Data cleaning

print("\nMissing Values")
print(df.isnull().sum())

df.drop_duplicates(inplace=True)


# Analysis

print("\nTotal Sales")
print(df["Sales"].sum())

print("\nAverage Sales")
print(df["Sales"].mean())

# Product-wise Sales

product_sales = df.groupby("Product")["Sales"].sum()

print("\nProduct Wise Sales")
print(product_sales)

# Region-wise Sales

region_sales = df.groupby("Region")["Sales"].sum()

print("\nRegion Wise Sales")
print(region_sales)


# Top Product

top_product = product_sales.idxmax()

print("\nBest Selling Product")
print(top_product)
# Out:
# Dataset
#      Product Region  Sales  Quantity
# 0     Tablet   East  46523         1
# 1  Headphone  South  27403         8
# 2     Laptop  South  23141         7
# 3     Tablet   West  19820        18
# 4     Tablet  South  45342         8
#
# Missing Values
# Product     0
# Region      0
# Sales       0
# Quantity    0
# dtype: int64
#
# Total Sales
# 2817893
#
# Average Sales
# 28178.93
#
# Product Wise Sales
# Product
# Headphone    740808
# Laptop       582689
# Mobile       764956
# Tablet       729440
# Name: Sales, dtype: int32
#
# Region Wise Sales
# Region
# East     821107
# North    691101
# South    541976
# West     763709
# Name: Sales, dtype: int32
#
# Best Selling Product
# Mobile

# %%
# Product Sales Chart

plt.figure(figsize=(7,5))

plt.bar(
    product_sales.index,
    product_sales.values
)

plt.title("Product Wise Sales")
plt.xlabel("Product")
plt.ylabel("Sales")

plt.show()

# %%
# Region Sales Chart

plt.figure(figsize=(7,5))

plt.pie(
    region_sales.values,
    labels=region_sales.index,
    autopct="%1.1f%%"
)

plt.title("Region Wise Sales")

plt.show()

# %%
# Sales Distribution

plt.figure(figsize=(7,5))

sns.histplot(
    df["Sales"],
    bins=10
)

plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")

plt.show()
