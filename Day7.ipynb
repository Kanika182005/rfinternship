# %%
import pandas as pd

# %%
Data = {
    "name":["Amit","Riya", "John"],
    "math": [80 , 90, 60],
    "science": [70,88,65],
    "english": [85, 92, 70]
}
df = pd.DataFrame(Data)
print(df)
# Out:
#    name  math  science  english
# 0  Amit    80       70       85
# 1  Riya    90       88       92
# 2  John    60       65       70

# %%
#calculate average marks per student
df["Average"] = (df["math"] + df["science"] + df["english"])/3
print(df)
# Out:
#    name  math  science  english    Average
# 0  Amit    80       70       85  78.333333
# 1  Riya    90       88       92  90.000000
# 2  John    60       65       70  65.000000

# %%
# find topper
topper_student= df()
